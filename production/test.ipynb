# %%
import pandas as pd 

my_list = [2,3,3,2,3]
obj = pd.Series(my_list, index=["a","b","c","d","e"])
obj[["d","b","a"]]
obj[obj>2]
obj*2
"b" in obj
"f" in obj
sdata = {"ohio": 500, "texas": 500, "oregon": 4344, "utah": 5000}
obj2 = pd.Series(sdata)




states = ["dhaka", "california", "ohio", "texas", "oregon", "utah"]
obj3 = pd.Series(sdata, index=states)
pd.isnull(obj3)
# Out:
# dhaka          True
# california     True
# ohio          False
# texas         False
# oregon        False
# utah          False
# dtype: bool

# %%
data = {"state": ["dhaka", "sylet", "rangpur", "panjab", "kumilla", "arab", "nowakhali"], "year":[2022, 2003,2004,2005, 2006, 2007,2008], "populations": [1.2,3.5,3.2,3.1,4.3,3,2]}

df = pd.DataFrame(data)
print(df)
# Out:
#        state  year  populations
# 0      dhaka  2022          1.2
# 1      sylet  2003          3.5
# 2    rangpur  2004          3.2
# 3     panjab  2005          3.1
# 4    kumilla  2006          4.3
# 5       arab  2007          3.0
# 6  nowakhali  2008          2.0

# %%
df.head(2)
# Out:
#    state  year  populations
# 0  dhaka  2022          1.2
# 1  sylet  2003          3.5

# %%
df.tail(2)
# Out:
#        state  year  populations
# 5       arab  2007          3.0
# 6  nowakhali  2008          2.0

# %%
df = pd.DataFrame(data, columns= ["year", "state", "populations"])
print(df)
# Out:
#    year      state  populations
# 0  2022      dhaka          1.2
# 1  2003      sylet          3.5
# 2  2004    rangpur          3.2
# 3  2005     panjab          3.1
# 4  2006    kumilla          4.3
# 5  2007       arab          3.0
# 6  2008  nowakhali          2.0

# %%
df = pd.DataFrame(data, columns= ["year", "state", "populations"], index= ["one", "two", "three", "four", "five", "six", "seven"])
print(df)
# Out:
#        year      state  populations
# one    2022      dhaka          1.2
# two    2003      sylet          3.5
# three  2004    rangpur          3.2
# four   2005     panjab          3.1
# five   2006    kumilla          4.3
# six    2007       arab          3.0
# seven  2008  nowakhali          2.0

# %%
df["year"]
# Out:
# one      2022
# two      2003
# three    2004
# four     2005
# five     2006
# six      2007
# seven    2008
# Name: year, dtype: int64

# %%
df["debt"] =12.3
print(df)
# Out:
#        year      state  populations  debt
# one    2022      dhaka          1.2  12.3
# two    2003      sylet          3.5  12.3
# three  2004    rangpur          3.2  12.3
# four   2005     panjab          3.1  12.3
# five   2006    kumilla          4.3  12.3
# six    2007       arab          3.0  12.3
# seven  2008  nowakhali          2.0  12.3

# %% [markdown]
# Read a excel file and work with it

# %%
data = pd.read_csv("IPL_data.csv")
data.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
data.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
data.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
data.shape
# Out:
# (950, 20)

# %%
len(data)
# Out:
# 950

# %%
data["country"] = "India"
data
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'country'],
#       dtype='object')

# %%
df = data[data["City"] == "Kolkata"]

# %% [markdown]
# selecting rows from a DataFrame

# %%
df = data.loc[2:3]

print(df)
# Out:
#         ID     City        Date Season  MatchNumber  \
# 2  1312198  Kolkata  2022-05-25   2022   Eliminator
# 3  1312197  Kolkata  2022-05-24   2022  Qualifier 1
#
#                          Team1                 Team2                  Venue  \
# 2  Royal Challengers Bangalore  Lucknow Super Giants  Eden Gardens, Kolkata
# 3             Rajasthan Royals        Gujarat Titans  Eden Gardens, Kolkata
#
#              TossWinner TossDecision  ...                  WinningTeam  \
# 2  Lucknow Super Giants        field  ...  Royal Challengers Bangalore
# 3        Gujarat Titans        field  ...               Gujarat Titans
#
#      WonBy Margin  method Player_of_Match  \
# 2     Runs   14.0     NaN      RM Patidar
# 3  Wickets    7.0     NaN       DA Miller
#
#                                         Team1Players  \
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
# ...

# %% [markdown]
# selecting rows in some interval

# %%
data.loc[0:10:2]
# Out:
#          ID         City        Date Season MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022       Final
# 2   1312198      Kolkata  2022-05-25   2022  Eliminator
# 4   1304116       Mumbai  2022-05-22   2022          70
# 6   1304114       Mumbai  2022-05-20   2022          68
# 8   1304112  Navi Mumbai  2022-05-18   2022          66
# 10  1304110  Navi Mumbai  2022-05-16   2022          64
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 4           Sunrisers Hyderabad           Punjab Kings
# 6           Chennai Super Kings       Rajasthan Royals
# 8          Lucknow Super Giants  Kolkata Knight Riders
# 10               Delhi Capitals           Punjab Kings
#
#                                  Venue            TossWinner TossDecision  \
# 0     Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# ...

# %%
data.loc[0:6]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
# 5  1304115     Mumbai  2022-05-21   2022           69
# 6  1304114     Mumbai  2022-05-20   2022           68
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
# 5               Delhi Capitals        Mumbai Indians
# 6          Chennai Super Kings      Rajasthan Royals
#
#                               Venue            TossWinner TossDecision  ...  \
# ...

# %% [markdown]
# find all the final winners from the data in differnt year

# %%
data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'country'],
#       dtype='object')

# %%
df = data[data["MatchNumber"] == "Final"]
df[["Season", "Team1", "TossWinner","Player_of_Match"]]
# Out:
#       Season                        Team1                   TossWinner  \
# 0       2022             Rajasthan Royals             Rajasthan Royals
# 74      2021          Chennai Super Kings        Kolkata Knight Riders
# 134  2020/21               Delhi Capitals               Delhi Capitals
# 194     2019               Mumbai Indians               Mumbai Indians
# 254     2018          Sunrisers Hyderabad          Chennai Super Kings
# 314     2017               Mumbai Indians               Mumbai Indians
# 373     2016  Royal Challengers Bangalore          Sunrisers Hyderabad
# 433     2015               Mumbai Indians          Chennai Super Kings
# 492     2014        Kolkata Knight Riders        Kolkata Knight Riders
# 552     2013          Chennai Super Kings               Mumbai Indians
# 628     2012        Kolkata Knight Riders          Chennai Super Kings
# 702     2011          Chennai Super Kings          Chennai Super Kings
# ...

# %% [markdown]
# How Many Matches CSK wins in Kolakata
# How many Supper over occured in the game

# %%
# number of Super Over
df = pd.read_csv("/home/sonjit/PythonProject/Pnadas_practice/production/data/input/inputdata.csv")
pf = df[df["Tour ID"].isnull()]
print(pf)
# Out:
#       New Tour Tour ID     Load #              Business Types  Canceled Load  \
# 1          NaN     NaN  116SRP4DJ       TransfersNonInventory          False
# 2          NaN     NaN  116QSQSHW             TrailerServices          False
# 3          NaN     NaN  114JBTDYF  TransfersUKStandardPallets          False
# 4          NaN     NaN  115MDWX7Z  TransfersUKStandardPallets          False
# 5          NaN     NaN  113GBYZTM  TransfersUKStandardPallets          False
# ...        ...     ...        ...                         ...            ...
# 6150       NaN     NaN  111KMRR32                 ATSOutbound          False
# 6151       NaN     NaN  1159YX16V                 ATSOutbound          False
# 6152       NaN     NaN  1118WGC9N                 ATSOutbound          False
# 6153       NaN     NaN  116V7CT8X                 ATSOutbound          False
# 6154       NaN     NaN  111M83RH8                 ATSOutbound          False
#
# ...
